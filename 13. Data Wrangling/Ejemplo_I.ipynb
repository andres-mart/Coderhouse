# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
        "key1": ["a", "a", "b", "b", "a"],

        "key2": ["one", "two", "one", "two", "one"],

        "data1": np.random.randn(5),

        "data2": np.random.randn(5),
    }
)

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.226239  0.044323
# 1    a  two -0.709135  1.213699
# 2    b  one -2.352161 -0.859270
# 3    b  two  1.138719 -1.044208
# 4    a  one  0.307599  0.616417

# %%
grouped = df["data1"].groupby(df["key1"])

# %%
grouped

# %%
grouped.mean()
# Out:
# key1
# a   -0.209258
# b   -0.606721
# Name: data1, dtype: float64

# %% [markdown]
# # Mas de un índice

# %%
means = df["data1"].groupby([df["key1"], df["key2"]]).mean()

# %%
means
# Out:
# key1  key2
# a     one     0.040680
#       two    -0.709135
# b     one    -2.352161
#       two     1.138719
# Name: data1, dtype: float64

# %%
df["data1"].groupby([df["key1"], df["key2"]]).aggregate(np.std)
# Out:
# key1  key2
# a     one     0.377481
#       two          NaN
# b     one          NaN
#       two          NaN
# Name: data1, dtype: float64

# %% [markdown]
# # Pivot

# %%
# importing pandas as pd
import pandas as pd

# creating a dataframe
df = pd.DataFrame(
    {
        "A": ["John", "Boby", "Mina"],
        "B": ["Masters", "Graduate", "Graduate"],
        "C": [27, 23, 21],
    }
)

# %%
df
# Out:
#       A         B   C
# 0  John   Masters  27
# 1  Boby  Graduate  23
# 2  Mina  Graduate  21

# %%
df.pivot(columns="B")
# Out:
#          A                C
# B Graduate Masters Graduate Masters
# 0      NaN    John      NaN    27.0
# 1     Boby     NaN     23.0     NaN
# 2     Mina     NaN     21.0     NaN

# %%
df.pivot(index="A", columns="B", values=["C"])
# Out:
#             C
# B    Graduate Masters
# A
# Boby     23.0     NaN
# John      NaN    27.0
# Mina     21.0     NaN

# %%
dfp = df.pivot(index="A", columns="B", values=["C", "A"])

# %%
df1 = pd.DataFrame(
    {
        "A": ["John", "Peter", "Mina"],

        "B": ["Masters", "Grade", "Graduate"],

        "C": [27, 23, 21],
    }
)

# %%
df1
# Out:
#        A         B   C
# 0   John   Masters  27
# 1  Peter     Grade  23
# 2   Mina  Graduate  21

# %%
df1.pivot(index="A", columns="B", values="C")
# Out:
# B      Grade  Graduate  Masters
# A
# John     NaN       NaN     27.0
# Mina     NaN      21.0      NaN
# Peter   23.0       NaN      NaN
