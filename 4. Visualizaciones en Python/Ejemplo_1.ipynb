# %% [markdown]
# ## Visualizaciones de datos en Python I

# %% [markdown]
# Comenzamos por un gráficos simples:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(1,21)
y= np.arange(101,121)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# Agregamos título y etiquetas:

# %%
x = np.arange(1,21)
y= np.arange(101,121)

fig, ax = plt.subplots()

# Título y etiquetas:
plt.title('Aprendiendo Matplotlib')
plt.xlabel('Valores Eje X')
plt.ylabel('Valores Eje Y')

ax.plot(x, y)
plt.show()

# %% [markdown]
# Valores puntuales en Eje X y Eje Y:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1,21)
y= np.arange(101,121)

fig, ax = plt.subplots()

plt.title('Aprendiendo Matplotlib')
plt.xlabel('Valores Eje X')
plt.ylabel('Valores Eje Y')

plt.xticks([5,10,15,20])
plt.yticks([100,105,110,115])

ax.plot(x, y)
plt.show()

# %% [markdown]
# Editamos la línea resultante:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1,21)
y= np.arange(101,121)

plt.figure(figsize=(10,5))

# Editamos los parámetros de la linea obtenida en el punto anterior:
plt.plot(x, y, color='purple', linewidth=5, linestyle='--', marker='v', markersize=20, markeredgecolor='black')

plt.title('Aprendiendo Matplotlib', fontdict={'fontsize':15})
plt.xlabel('Valores Eje X')
plt.ylabel('Valores Eje Y')

plt.xticks([5,10,15,20])
plt.yticks([100,105,110,115])

ax.plot(x, y)
plt.show()

# %% [markdown]
# Agregamos una segunda línea y leyendas:

# %%
x = np.arange(1,21)
y= x*5
y2= x*2
plt.figure(figsize=(10,5))

plt.plot(x, y, color='purple', linewidth=5, linestyle='--', marker='v', markersize=20, markeredgecolor='black')
plt.plot(x, y2, color='green')

plt.title('Aprendiendo Matplotlib', fontdict={'fontsize':15})
plt.xlabel('Valores Eje X')
plt.ylabel('Valores Eje Y')

plt.xticks([5,10,15,20])


ax.plot(x, y)
plt.show()

# %% [markdown]
# Guardamos nuestro gráfico:

# %%
x = np.arange(1,21)
y= x*5
y2= x*2
plt.figure(figsize=(10,5))

plt.plot(x, y, color='purple', linewidth=5, linestyle='--', marker='v', markersize=20, markeredgecolor='black')
plt.plot(x, y2, color='green')

plt.title('Aprendiendo Matplotlib', fontdict={'fontsize':15})
plt.xlabel('Valores Eje X')
plt.ylabel('Valores Eje Y')

plt.xticks([5,10,15,20])

plt.savefig('Graph_viz.png')

plt.show()

# %% [markdown]
# ## Barcharts

# %%
etiquetas = ['A','B','C','D','E']
valores = [1,3,6,4,5]

plt.bar(etiquetas, valores)
plt.show()

# %% [markdown]
# Editamos el Barchart:

# %%
etiquetas = ['A','B','C','D','E']
valores = [1,3,6,4,5]

barra = plt.bar(etiquetas, valores, color='magenta')

barra[0].set_hatch('/')
barra[1].set_hatch('*')
barra[2].set_hatch('-')

plt.show()

# %% [markdown]
# Agregamos una línea de valor promedio:

# %%
etiquetas = ['A','B','C','D','E']
valores = [1,3,6,4,5]

barra = plt.bar(etiquetas, valores, color='magenta')

barra[0].set_hatch('/')
barra[1].set_hatch('*')
barra[2].set_hatch('-')

promedio = np.mean(valores)
plt.axhline(promedio, color='darkblue')

plt.show()

# %% [markdown]
# ## Scatter Plots:

# %%
x= np.arange(1,21)
y= x*2

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Duplicamos los marcadores del Scatterplot:

# %%
x= np.arange(1,8)
y= x*2
s=[20*2**n for n in range(len(x))]

plt.scatter(x, y, s=s)

plt.show()
